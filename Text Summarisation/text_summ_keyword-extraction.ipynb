# %%
from gensim.summarization.summarizer import summarize 
from gensim.summarization import keywords 
from spellchecker import SpellChecker 
from nltk.corpus import wordnet
from nltk.corpus.reader.wordnet import WordNetError
from itertools import product


def get_word_synonyms_from_sent(word, sent):
    word_synonyms = []
    for synset in wordnet.synsets(word):
        for lemma in synset.lemma_names():
            if lemma in sent and lemma != word:
                word_synonyms.append(lemma)
    return word_synonyms

def get(word, sent):
    word_synonyms = []
    for synset in wordnet.synsets(word):
        for lemma in synset.lemma_names():
            word_synonyms.append(lemma)
    return word_synonyms
            

with open('wikicontent.txt', 'r') as file:
    data = file.read().replace('\n', '')
    
print("Original text"+"\n")
print(data)
print("\n")
m2=data
spell = SpellChecker() 
data=data.replace('vv','w')
data=data.replace('uu','w')
# find those words that may be misspelled 

word = data.split(' ')
z=[]
for x in word:
    z.append(spell.correction(x))

m=' '
data=m.join(z)
print('data:-'+'\n'+data)
summ_per = summarize(m2, ratio = 0.2) 
print("Percent summary"+"\n") 
print(summ_per) 


print("\n")
print("Keywords:-"+"\n")
a=keywords(data).split('\n') 
for i in summ_per.split(' '):
    a.append(i)
    
w = ['communicable','lung','antibiotics','bacteria','Mycobacterium','6 months']
count=0
print(a)
for word in w:
    if word in a:
        print ("MATCH FOR '" + word.upper() + "' FOUND IN THE SENTENCE" )
        count=count+1
    else:
        word_synonyms = get_word_synonyms_from_sent(word, a)
        if word_synonyms:
            print ("SYNONYMS FOR '" + word.upper() + "' FOUND IN THE SENTENCE: " + ", ".join(word_synonyms))
            count=count+1
        else:
            print ("NO MATCH FOUND FOR '" + word.upper() + "' FOUND IN THE SENTENCE" )

score=count/len(w)
score=score*5
if (score-round(score))>0.5:
    score=round(score)+1
elif (score-round(score))>0.25:
    score=round(score)+0.5
else:
    score=round(score)
print('Marks awarded : {}/{}'.format(score,5))
# Out:
# Original text
#
# It is a bacterial disease that mainly affects the lungs causing great discomfort.It is a chronic lung diseaseThe bacteria that cause TB are spread when an infected person coughs or sneezes.Tuberculosis generally affects the lungs, but can also affect other parts of the body.Most people infected with the bacteria that cause tuberculosis don't have symptoms. When symptoms do occur, they usually include a cough (sometimes blood-tinged), weight loss, night sweats and fever.Treatment isn't always required for those without symptoms. Patients with active symptoms will require a long course of treatment involving multiple antibiotics .Tuberculosis (TB) is a contagious disease usually caused by Mycobacterium tuberculosis (MTB) bacteria Tuberculosis generally affects the lungs, but can also affect other parts of the body. Most infections show no symptoms, in which case it is known as latent tuberculosis. About 10% of latent infections progress to active disease which, if left untreated, kills about half of those affected.More than 95% of deaths occurred in developing countries, and more than 50% in India, China, Indonesia, Pakistan, and the Philippines. The number of new cases each year has decreased since 2000.About 80% of people in many Asian and African countries test positive while 5â€“10% of people in the United States population test positive by the tuberculin test. Tuberculosis has been present in humans since ancient times.It's treatment was discovered to be antibiotics.Antibiotics help get most of the patients healthy.
#
#
# data:-
# It is a bacterial disease that mainly affects the lungs causing great discomfort.It is a chronic lung diseaseThe bacteria that cause TB are spread when an infected person coughs or sneezes.Tuberculosis generally affects the lungs but can also affect other parts of the body.Most people infected with the bacteria that cause tuberculosis don't have symptoms When symptoms do occur they usually include a cough sometimes blood-tinged), weight loss night sweats and fever.Treatment n't always required for those without symptoms Patients with active symptoms will require a long course of treatment involving multiple antibiotics tuberculosis tb is a contagious disease usually caused by Mycobacterium tuberculosis mtb bacteria Tuberculosis generally affects the lungs but can also affect other parts of the body. Most infections show no symptoms in which case it is known as latent tuberculosis About m0 of latent infections progress to active disease which if left untreated kills about half of those affected.More than p5 of deaths occurred in developing countries and more than m50 in india china indonesia pakistan and the philippines The number of new cases each year has decreased since 2000.About m0 of people in many Asian and African countries test positive while 5â€“10% of people in the United States population test positive by the tuberculin test Tuberculosis has been present in humans since ancient times.It's treatment was discovered to be antibiotics.Antibiotics help get most of the patients healthy
# Percent summary
#
# Patients with active symptoms will require a long course of treatment involving multiple antibiotics .Tuberculosis (TB) is a contagious disease usually caused by Mycobacterium tuberculosis (MTB) bacteria Tuberculosis generally affects the lungs, but can also affect other parts of the body.
#
#
# Keywords:-
#
# ['tuberculosis', 'test', 'infected', 'infections', 'disease', 'antibiotics', 'cause', 'caused', 'countries', 'lungs causing', 'untreated', 'usually', 'lung', 'china indonesia', 'bacteria', 'Patients', 'with', 'active', 'symptoms', 'will', 'require', 'a', 'long', 'course', 'of', 'treatment', 'involving', 'multiple', 'antibiotics', '.Tuberculosis', '(TB)', 'is', 'a', 'contagious', 'disease', 'usually', 'caused', 'by', 'Mycobacterium', 'tuberculosis', '(MTB)', 'bacteria', 'Tuberculosis', 'generally', 'affects', 'the', 'lungs,', 'but', 'can', 'also', 'affect', 'other', 'parts', 'of', 'the', 'body.']
# SYNONYMS FOR 'COMMUNICABLE' FOUND IN THE SENTENCE: contagious
# MATCH FOR 'LUNG' FOUND IN THE SENTENCE
# MATCH FOR 'ANTIBIOTICS' FOUND IN THE SENTENCE
# MATCH FOR 'BACTERIA' FOUND IN THE SENTENCE
# MATCH FOR 'MYCOBACTERIUM' FOUND IN THE SENTENCE
# NO MATCH FOUND FOR '6 MONTHS' FOUND IN THE SENTENCE
# Marks awarded : 4/5
