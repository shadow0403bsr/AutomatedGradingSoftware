# %%
from gensim.summarization.summarizer import summarize 
from gensim.summarization import keywords 
from spellchecker import SpellChecker 
from nltk.corpus import wordnet
from nltk.corpus.reader.wordnet import WordNetError
from itertools import product


def get_word_synonyms_from_sent(word, sent):
    word_synonyms = []
    for synset in wordnet.synsets(word):
        for lemma in synset.lemma_names():
            if lemma in sent and lemma != word:
                word_synonyms.append(lemma)
    return word_synonyms

def get(word, sent):
    word_synonyms = []
    for synset in wordnet.synsets(word):
        for lemma in synset.lemma_names():
            word_synonyms.append(lemma)
    return word_synonyms
            

with open('sample_answer.txt', 'r') as file:
    data = file.read().replace('\n', '')
    
print("Original text"+"\n")
print(data)
print("\n")
m2=data
spell = SpellChecker() 
data=data.replace('vv','w')
data=data.replace('uu','w')
# find those words that may be misspelled 

word = data.split(' ')
z=[]
for x in word:
    z.append(spell.correction(x))

m=' '
data=m.join(z)
print('data:-'+'\n'+data)
summ_per = summarize(m2, ratio = 0.2) 
print("Percent summary"+"\n") 
print(summ_per) 


print("\n")
print("Keywords:-"+"\n")
a=keywords(data).split('\n') 
for i in summ_per.split(' '):
    a.append(i)
    
w = ['street','last','antibiotics','silence','shadow']
count=0
print(a)
for word in w:
    if word in a:
        print ("MATCH FOR '" + word.upper() + "' FOUND IN THE SENTENCE" )
        count=count+1
    else:
        word_synonyms = get_word_synonyms_from_sent(word, a)
        if word_synonyms:
            print ("SYNONYMS FOR '" + word.upper() + "' FOUND IN THE SENTENCE: " + ", ".join(word_synonyms))
            count=count+1
        else:
            print ("NO MATCH FOUND FOR '" + word.upper() + "' FOUND IN THE SENTENCE" )

score=count/len(w)
score=score*5
if (score-round(score))>0.5:
    score=round(score)+1
elif (score-round(score))>0.25:
    score=round(score)+0.5
else:
    score=round(score)
print('Marks awarded : {}/{}'.format(score,5))
# Out:
# Original text
#
# I upas a music friend fool tune beat last club one the clone closer feature. downloact rale song subscriebe token sale advert breakeng news as details emerp. about rock provide apYeared low middle reducing pnoving fast far few fgn little. time and changes lanp net in toenty states oote drivers liance stm street. despite over wen story rich than then who will glory hoarse result typically. sore nose at poor voice skouting rohisper boot two miss numbers team building. north rochet vvrong gray fed fill mincl need release ciare take care trace leave. amilable least failure better everything got home pmm school arm minute. fault bog girl nothing silence wake woke beinvg stay cause after let v future. tooth yes no kappens out cash asino world npord finall finance bond have with. fellonr computer key keyboard board screen frll null true fwlee pw work job. strdont stop possible suspenct people us bekind loan wolees tell tald look looks. silence televesion volermee him ber his wdeout rules beautiful gun wild. shooting shot shod little mx like ths shark power position sign loose finel. place shouxder garelen grass tree branch git cw pure wd stick desk aw stair dwam. amage doto present post if crlone cause prmise heavy toniglt pocket too. alueays lyric let last step road all noteing foreoer child fair actually blfore. prlfer original track drop piano guitor guita since oesterday coin bit hyle ty. buy bought rccent act advif next exit best lws hope aout where when vohy se ww m. city fake top lik lanes indeed inside side ovcr here gesiM great cdn offniol. video farm pg ham han corS rosl roll crazy rock gone part zeall street bbx ehkw. gdde lostj dld relax fire sea anycokere direct or love rest Bj cancley leve. trend nicro dawn skadoo stile myself suit sex bird ay verzion girl boy plcin. poss pomion ear lead leg uee sweet master beil slide form lap romp cuw drama. evflect Gain lf.
#
#
# data:-
# I ups a music friend fool tune beat last club one the clone closer features download rate song subscribe token sale advert breaking news as details emerge about rock provide appeared low middle reducing proving fast far few fun little time and changes land net in twenty states note drivers lance stm street despite over wen story rich than then who will glory hoarse result typically sore nose at poor voice shouting whisper boot two miss numbers team building north rocket wrong gray fed fill mince need release care take care trace leave amiable least failure better everything got home mm school arm minutes fault bog girl nothing silence wake woke being stay cause after let v future tooth yes no happens out cash amino world nord final finance bond have with fellow computer key keyboard board screen full null true flee pw work job strong stop possible suspect people us behind loan wolves tell told look looks silence television volermee him ber his debut rules beautiful gun wild shooting shot shod little mx like the shark power position sign loose finely place shoulder green grass tree branch git cw pure wd stick desk aw stair drama damage dot present post if clone cause promise heavy tonight pocket too always lyric let last step road all nothing forever child fair actually before prefer original track drop piano guitar guitar since yesterday coin bit hole t. buy bought recent act david next exit best laws hope about where when very se ww m. city fake top lik lanes indeed inside side over here grim great can offniol. video farm pg ham han cos rose roll crazy rock gone part zeal street box e.w. gide lost did relax fire sea anycokere direct or love rest Bj cantley level trend micro dawn shadow stile myself suit sex bird ay version girl boy plain poss potion ear lead leg see sweet master bell slide form lap romp cut drama effect Gain f.
# Percent summary
#
# about rock provide apYeared low middle reducing pnoving fast far few fgn little.
# time and changes lanp net in toenty states oote drivers liance stm street.
# fault bog girl nothing silence wake woke beinvg stay cause after let v future.
# shooting shot shod little mx like ths shark power position sign loose finel.
# video farm pg ham han corS rosl roll crazy rock gone part zeall street bbx ehkw.
#
#
# Keywords:-
#
# ['street', 'drama', 'little', 'cause', 'girl', 'rock', 'true', 'anycokere', 'sex', 'story', 'tooth', 'video', 'land', 'silence', 'look looks', 'child fair', 'keyboard board', 'best laws', 'coin bit', 'friend fool tune', 'voice shouting whisper', 'bought recent act', 'sore', 'hoarse', 'suspect', 'job', 'need', 'leave', 'amino', 'finance', 'level', 'shadow', 'note', 'gray', 'numbers', 'rules', 'about', 'rock', 'provide', 'apYeared', 'low', 'middle', 'reducing', 'pnoving', 'fast', 'far', 'few', 'fgn', 'little.\ntime', 'and', 'changes', 'lanp', 'net', 'in', 'toenty', 'states', 'oote', 'drivers', 'liance', 'stm', 'street.\nfault', 'bog', 'girl', 'nothing', 'silence', 'wake', 'woke', 'beinvg', 'stay', 'cause', 'after', 'let', 'v', 'future.\nshooting', 'shot', 'shod', 'little', 'mx', 'like', 'ths', 'shark', 'power', 'position', 'sign', 'loose', 'finel.\nvideo', 'farm', 'pg', 'ham', 'han', 'corS', 'rosl', 'roll', 'crazy', 'rock', 'gone', 'part', 'zeall', 'street', 'bbx', 'ehkw.']
# MATCH FOR 'STREET' FOUND IN THE SENTENCE
# SYNONYMS FOR 'LAST' FOUND IN THE SENTENCE: net
# NO MATCH FOUND FOR 'ANTIBIOTICS' FOUND IN THE SENTENCE
# MATCH FOR 'SILENCE' FOUND IN THE SENTENCE
# MATCH FOR 'SHADOW' FOUND IN THE SENTENCE
# Marks awarded : 4/5
